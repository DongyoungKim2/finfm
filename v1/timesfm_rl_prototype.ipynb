# %%
import os
import datetime as dt
from typing import List, Optional

import numpy as np
import pandas as pd
import yfinance as yf
import torch
import torch.nn as nn

import timesfm
from peft import LoraConfig, get_peft_model

import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_vec_env

# never set explicit colors per instructions
import matplotlib.pyplot as plt
import vectorbt as vbt

# %%
# =====================================================================
# Configuration
# =====================================================================
CONFIG = {
    "tickers": ["AAPL", "MSFT", "NVDA", "GOOGL", "AMZN"],
    "macro":   ["^GSPC", "^VIX"],
    "start":   "2015-01-01",
    "end":     dt.date.today().isoformat(),
    "window":  256,
    "horizon": 1,
    "train_ratio": 0.8,
    "device":  "cuda" if torch.cuda.is_available() else "cpu",
    "lora_r":  8,
    "ppo_steps": 200_000,
    "seed":    42,
}

# Directories
DATA_DIR = "./data"
MODEL_DIR = "./models"
PLOT_DIR = "./plots"
LOG_DIR = "./logs"
for d in [DATA_DIR, MODEL_DIR, PLOT_DIR, LOG_DIR]:
    os.makedirs(d, exist_ok=True)

# Set seeds
np.random.seed(CONFIG["seed"])
torch.manual_seed(CONFIG["seed"])
if CONFIG["device"] == "cuda":
    torch.cuda.manual_seed_all(CONFIG["seed"])

# %%
# =====================================================================
# 1. Data Download & Pre‑processing
# =====================================================================

def download_prices(tickers: List[str], start: str, end: str) -> pd.DataFrame:
    df = yf.download(tickers, start=start, end=end,
                     group_by="ticker", progress=False, auto_adjust=True)
    closes = pd.concat({t: df[t]["Close"] for t in tickers}, axis=1)
    closes.columns = pd.Index(tickers, name="ticker")
    closes = closes.resample("1D").ffill()
    return closes

print("Downloading data …")
price_df = download_prices(
    CONFIG["tickers"] + CONFIG["macro"], CONFIG["start"], CONFIG["end"]
)
price_df.to_csv(f"{DATA_DIR}/prices.csv")

# Split into train / test
split_idx = int(len(price_df) * CONFIG["train_ratio"])
train_df = price_df.iloc[:split_idx]
val_df = price_df.iloc[split_idx:]
# Out:
# Downloading data …

# %%
# =====================================================================
# 2. Dataset & DataLoader (unchanged)
# =====================================================================

class MultiAssetDataset(torch.utils.data.Dataset):
    def __init__(self, df: pd.DataFrame, window: int, horizon: int, target_ticker: str):
        self.df = df
        self.window = window
        self.horizon = horizon
        self.target_idx = df.columns.get_loc(target_ticker)

    def __len__(self):
        return len(self.df) - self.window - self.horizon

    def __getitem__(self, idx):
        window_slice = self.df.iloc[idx: idx + self.window].values.astype(np.float32)
        future_price = self.df.iloc[idx + self.window + self.horizon - 1, self.target_idx].astype(np.float32)
        return window_slice, future_price

# %%
# =====================================================================
# 3. Model Definition (Encoder → TimesFM → Head)
# =====================================================================

class Encoder(nn.Module):
    def __init__(self, n_channels: int, d_model: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(n_channels, d_model, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv1d(d_model, d_model, kernel_size=3, padding=1),
            nn.ReLU(),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.permute(0, 2, 1)
        h = self.net(x)
        return h.permute(0, 2, 1)

class TimesFMWrapper(nn.Module):
    def __init__(self, n_channels: int, d_model: int = 512):
        super().__init__()
        self.encoder = Encoder(n_channels, d_model)
        self.core = timesfm.TimesFm(
            hparams=timesfm.TimesFmHparams(
                backend="gpu" if CONFIG["device"] == "cuda" else "cpu",
                per_core_batch_size=CONFIG["lora_r"],
                horizon_len=CONFIG["horizon"],
            ),
            checkpoint=timesfm.TimesFmCheckpoint(
                huggingface_repo_id="google/timesfm-1.0-200m-pytorch",
            ),
        )
        # Freeze TimesFM core
        if isinstance(self.core, nn.Module):
            for p in self.core.parameters():
                p.requires_grad = False

        self.head = nn.Linear(d_model, 1)
        # Apply LoRA to head
        try:
            lora_cfg = LoraConfig(
                r=CONFIG["lora_r"],
                lora_alpha=CONFIG["lora_r"] * 2,
                target_modules=["linear"],
                bias="none",
            )
            self.head = get_peft_model(self.head, lora_cfg)
        except ValueError as e:
            print("[WARN] LoRA adaptation skipped:", e)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h = self.encoder(x)
        y_hat = self.core(h)
        out = self.head(y_hat[:, -1, :])
        return out.squeeze(-1)

# %%
# =====================================================================
# 4. Gym Environment with Price-Delta Reward
# =====================================================================

class StockForecastEnv(gym.Env):
    metadata = {"render_modes": ["human"]}

    def __init__(self, df: pd.DataFrame, target: str):
        super().__init__()
        self.df = df.values.astype(np.float32)
        self.target_idx = df.columns.get_loc(target)
        self.window = CONFIG["window"]
        self.horizon = CONFIG["horizon"]
        self.current_step = 0
        self.action_space = gym.spaces.Box(low=-10.0, high=10.0, shape=(1,), dtype=np.float32)
        self.observation_space = gym.spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(self.window, df.shape[1]), dtype=np.float32
        )

    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        self.current_step = 0
        obs = self.df[:self.window]
        return obs, {}

    def step(self, action: np.ndarray):
        pred_pct = float(np.tanh(action.item()) * 0.05)
        idx_now = self.current_step + self.window - 1
        idx_next = idx_now + 1
        price_now = self.df[idx_now, self.target_idx]
        price_next = self.df[idx_next, self.target_idx]
        log_ret = float(np.log(price_next / price_now + 1e-8))
        reward = pred_pct * log_ret
        self.current_step += 1
        done = (self.current_step + self.window + self.horizon) >= len(self.df)
        if not done:
            obs = self.df[self.current_step: self.current_step + self.window]
        else:
            obs = np.zeros((self.window, self.df.shape[1]), dtype=np.float32)
        info = {"log_return": log_ret, "pred_pct": pred_pct}
        return obs, reward, done, False, info

# %%
# =====================================================================
# 5. Train PPO
# =====================================================================

def train_ppo(target: str):
    env_fn = lambda: Monitor(StockForecastEnv(train_df, target))
    vec_env = make_vec_env(env_fn, n_envs=1, seed=CONFIG["seed"], monitor_dir=LOG_DIR)
    model = PPO(
        "MlpPolicy", vec_env,
        verbose=1,
        tensorboard_log="./ppo_tb",
        learning_rate=1e-4,
        n_steps=4096,
        policy_kwargs=dict(net_arch=[256, 256]),
        gae_lambda=0.9,
        device=CONFIG["device"],
    )
    model.learn(total_timesteps=CONFIG["ppo_steps"])
    model.save(f"{MODEL_DIR}/ppo_{target}")
    vec_env.close()


print(f"Training PPO for {ticker} …")
train_ppo(ticker)
# Out:
# Training PPO for AAPL …
# Using cuda device
# Logging to ./ppo_tb/PPO_5
# /opt/conda/envs/finfm311/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.81e+03 |
# |    ep_rew_mean     | 0.0456   |
# | time/              |          |
# |    fps             | 847      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | 0.0367        |
# | time/                   |               |
# |    fps                  | 584           |
# |    iterations           | 2             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00014681811 |
# |    clip_fraction        | 0.00703       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.256         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.00926       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | 0.000274      |
# |    std                  | 0.994         |
# |    value_loss           | 0.0169        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | -0.0032      |
# | time/                   |              |
# |    fps                  | 536          |
# |    iterations           | 3            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0037001083 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00103     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000466    |
# |    std                  | 0.986        |
# |    value_loss           | 0.000518     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.00297     |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003111444 |
# |    clip_fraction        | 0.00959     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.0369      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00605     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000368   |
# |    std                  | 0.978       |
# |    value_loss           | 0.000798    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | 0.00238       |
# | time/                   |               |
# |    fps                  | 489           |
# |    iterations           | 5             |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 9.4019866e-05 |
# |    clip_fraction        | 0.00403       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.078         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.00115       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 9e-05         |
# |    std                  | 0.982         |
# |    value_loss           | 0.000362      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.00254      |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 6            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0011895292 |
# |    clip_fraction        | 0.00393      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0159       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.012       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 0.000297     |
# |    std                  | 0.969        |
# |    value_loss           | 0.000379     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | -0.00477     |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 7            |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0040540523 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0177       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0236       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 0.968        |
# |    value_loss           | 0.000214     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | -0.00604    |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 8           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002108684 |
# |    clip_fraction        | 0.00166     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00262     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00777    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000283   |
# |    std                  | 0.953       |
# |    value_loss           | 0.00038     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | -0.00264     |
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 9            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0036205226 |
# |    clip_fraction        | 0.00955      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00438      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00133     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000193    |
# |    std                  | 0.938        |
# |    value_loss           | 0.000123     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | -0.00385    |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 10          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002859937 |
# |    clip_fraction        | 0.00837     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00049    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0244     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000263   |
# |    std                  | 0.925       |
# |    value_loss           | 0.000149    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | -0.00284      |
# | time/                   |               |
# |    fps                  | 470           |
# |    iterations           | 11            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00095604075 |
# |    clip_fraction        | 2.44e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.00149      |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.00181      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.00014       |
# |    std                  | 0.921         |
# |    value_loss           | 0.000106      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | -0.00304     |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 12           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035012886 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.000347    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0239       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00138     |
# |    std                  | 0.912        |
# |    value_loss           | 0.000165     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | -0.00347     |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 13           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0015850866 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.000636    |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00359     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.000343     |
# |    std                  | 0.913        |
# |    value_loss           | 0.000109     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | -0.00307    |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 14          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004172392 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -9.08e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00611    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000625   |
# |    std                  | 0.915       |
# |    value_loss           | 7.73e-05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | -0.00201      |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 15            |
# |    time_elapsed         | 132           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00012090754 |
# |    clip_fraction        | 0.000366      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 3.84e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.00022      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 7.79e-05      |
# |    std                  | 0.919         |
# |    value_loss           | 0.000129      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 5.91e-06     |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 16           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0057776044 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.00143      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0173      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00342     |
# |    std                  | 0.908        |
# |    value_loss           | 4.88e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.00151      |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 17           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0017499002 |
# |    clip_fraction        | 0.00295      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000503     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0137       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -7.13e-05    |
# |    std                  | 0.894        |
# |    value_loss           | 0.000102     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.00364     |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 18          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004065496 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.00853     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00353    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00281    |
# |    std                  | 0.887       |
# |    value_loss           | 4.95e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.00532      |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 19           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0054031685 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.0022      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0046       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000729    |
# |    std                  | 0.869        |
# |    value_loss           | 5.61e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.00716     |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 20          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005091609 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.0112     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00975    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00134    |
# |    std                  | 0.865       |
# |    value_loss           | 5.52e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.00926      |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 21           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0017598798 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.000572     |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00837     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000535    |
# |    std                  | 0.86         |
# |    value_loss           | 5.95e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0127       |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 22           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0035707948 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.0021       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0176       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000248    |
# |    std                  | 0.853        |
# |    value_loss           | 0.000102     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.014       |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 23          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003962342 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.0025      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00717     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.848       |
# |    value_loss           | 9.41e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0142       |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 24           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0027813537 |
# |    clip_fraction        | 0.00591      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.00483      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00889     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00081     |
# |    std                  | 0.835        |
# |    value_loss           | 2.68e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0156      |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 25          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005672993 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.00502     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0178     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.828       |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0158       |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 26           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0029160006 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0159       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0201       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000932    |
# |    std                  | 0.826        |
# |    value_loss           | 5.98e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0182      |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 27          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004492337 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.091       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00674     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00124    |
# |    std                  | 0.816       |
# |    value_loss           | 5.48e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0196      |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 28          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.004524095 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0157      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0147     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000117   |
# |    std                  | 0.806       |
# |    value_loss           | 2.55e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0215       |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 29           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0011577453 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0357       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00683      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000145     |
# |    std                  | 0.798        |
# |    value_loss           | 3.69e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | 0.0221        |
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 30            |
# |    time_elapsed         | 267           |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 0.00011636583 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | 0.0134        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.00226      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.000171      |
# |    std                  | 0.8           |
# |    value_loss           | 7.78e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | 0.0235        |
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 31            |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# |    approx_kl            | 0.00020382997 |
# |    clip_fraction        | 0.00161       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | 0.0211        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.00232      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000305     |
# |    std                  | 0.812         |
# |    value_loss           | 4.12e-05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | 0.0241        |
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 32            |
# |    time_elapsed         | 285           |
# |    total_timesteps      | 131072        |
# | train/                  |               |
# |    approx_kl            | 0.00056648534 |
# |    clip_fraction        | 0.00198       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.21         |
# |    explained_variance   | 0.0313        |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.00166       |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 0.000302      |
# |    std                  | 0.813         |
# |    value_loss           | 5.89e-06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0251      |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 33          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.004837225 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0235      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00937     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00171    |
# |    std                  | 0.809       |
# |    value_loss           | 2.96e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0258       |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 34           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0005313108 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.000225     |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00505     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000217     |
# |    std                  | 0.81         |
# |    value_loss           | 0.000124     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.81e+03      |
# |    ep_rew_mean          | 0.027         |
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 35            |
# |    time_elapsed         | 312           |
# |    total_timesteps      | 143360        |
# | train/                  |               |
# |    approx_kl            | 0.00034091354 |
# |    clip_fraction        | 0.00151       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | -0.00136      |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.00234      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -3.12e-05     |
# |    std                  | 0.823         |
# |    value_loss           | 7.44e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0283       |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 36           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 7.028415e-05 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.00149     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00212      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00044      |
# |    std                  | 0.827        |
# |    value_loss           | 1.35e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.029       |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 37          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.002934189 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0146      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00131     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000458   |
# |    std                  | 0.829       |
# |    value_loss           | 5.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0305      |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 38          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.001969264 |
# |    clip_fraction        | 0.00811     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0166      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00157    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -3.64e-05   |
# |    std                  | 0.83        |
# |    value_loss           | 7.12e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0312       |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 39           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0037323115 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.00132      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0068      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 2.86e-05     |
# |    std                  | 0.833        |
# |    value_loss           | 9.33e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0332      |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 40          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.004870318 |
# |    clip_fraction        | 0.0216      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.00813     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00395    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.83        |
# |    value_loss           | 3.51e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0335       |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 41           |
# |    time_elapsed         | 365          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0011369431 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.00731      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.000517     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -1.44e-05    |
# |    std                  | 0.829        |
# |    value_loss           | 4.76e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0347       |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 42           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0035212105 |
# |    clip_fraction        | 0.00725      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0452       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0108       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000345    |
# |    std                  | 0.829        |
# |    value_loss           | 2.71e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0351       |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 43           |
# |    time_elapsed         | 384          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0023418358 |
# |    clip_fraction        | 0.00227      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0224       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00255      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -8.26e-05    |
# |    std                  | 0.821        |
# |    value_loss           | 6e-06        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0364      |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 44          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.004587738 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.053       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00149    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00115    |
# |    std                  | 0.82        |
# |    value_loss           | 4.63e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.81e+03   |
# |    ep_rew_mean          | 0.0373     |
# | time/                   |            |
# |    fps                  | 457        |
# |    iterations           | 45         |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.00349641 |
# |    clip_fraction        | 0.016      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.0216     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0045     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.000827  |
# |    std                  | 0.819      |
# |    value_loss           | 1.23e-05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0384       |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 46           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0021150853 |
# |    clip_fraction        | 0.00271      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0365       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00272     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000138    |
# |    std                  | 0.811        |
# |    value_loss           | 1.35e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.039       |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 47          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.005407925 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.00522    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00421     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00134    |
# |    std                  | 0.812       |
# |    value_loss           | 8.37e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 0.0395      |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 48          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.003937183 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.00896     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.000498   |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.806       |
# |    value_loss           | 1.62e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.81e+03     |
# |    ep_rew_mean          | 0.0409       |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 49           |
# |    time_elapsed         | 438          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0031750542 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0211       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.000163    |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00107     |
# |    std                  | 0.808        |
# |    value_loss           | 1.38e-05     |
# ------------------------------------------
